# %% [markdown]
# # Relatório de análise 8

# %% [markdown]
# ## Identificando e removendo outliers

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (14,6))

# %%
dados = pd.read_csv("aluguel_residencial.csv", sep = ';')
dados.head(10)
# Out:
#                  Tipo               Bairro  ...  Valor m2  Tipo Agregado
# 0           Quitinete           Copacabana  ...     42.50    Apartamento
# 1                Casa      Jardim Botânico  ...     70.00           Casa
# 2         Apartamento               Centro  ...     53.33    Apartamento
# 3         Apartamento         Higienópolis  ...     16.67    Apartamento
# 4         Apartamento             Cachambi  ...     26.00    Apartamento
# 5  Casa de Condomínio      Barra da Tijuca  ...     29.33           Casa
# 6  Casa de Condomínio                Ramos  ...     15.38           Casa
# 7         Apartamento               Grajaú  ...     21.43    Apartamento
# 8         Apartamento  Lins de Vasconcelos  ...     16.67    Apartamento
# 9         Apartamento           Copacabana  ...     50.00    Apartamento
#
# [10 rows x 11 columns]

# %%
dados.boxplot(['Valor'])

# %%
dados[dados['Valor'] >= 500000]
# Out:
#                      Tipo                    Bairro  ...  Valor m2  Tipo Agregado
# 7629          Apartamento           Barra da Tijuca  ...   9230.77    Apartamento
# 10636  Casa de Condomínio   Freguesia (Jacarepaguá)  ...   4907.98           Casa
# 12661         Apartamento   Freguesia (Jacarepaguá)  ...   3666.67    Apartamento
# 13846         Apartamento  Recreio dos Bandeirantes  ...   7485.03    Apartamento
# 15520         Apartamento                  Botafogo  ...  15000.00    Apartamento
#
# [5 rows x 11 columns]

# %%
valor = dados['Valor']

# %%
Q1 = valor.quantile(.25) #calcula o primeiro quartil
Q3 = valor.quantile(.75) #calcula o terceiro quartil
IIQ = Q3 - Q1 #calcula o intervalo entre quartis
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor >= limite_inferior) & (valor <= limite_superior)
dados_new = dados[selecao]
dados_new.boxplot(['Valor'])

# %%
dados.hist(['Valor'])
dados_new.hist(['Valor'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc22dfb4128>]],
#       dtype=object)

# %% [markdown]
# ## Identificando e removendo outliers (continuação)

# %%
dados.boxplot(['Valor'], by = ['Tipo'])

# %%
grupo_tipo = dados.groupby('Tipo')['Valor']
type(grupo_tipo)
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
grupo_tipo.groups
# Out:
# {'Apartamento': Int64Index([    2,     3,     4,     7,     8,     9,    11,    13,    14,
#                 15,
#              ...
#              21813, 21814, 21816, 21817, 21818, 21819, 21821, 21823, 21824,
#              21825],
#             dtype='int64', length=18780),
#  'Casa': Int64Index([    1,    22,    54,    57,    96,   100,   144,   160,   180,
#                238,
#              ...
#              21582, 21606, 21614, 21667, 21672, 21699, 21756, 21781, 21793,
#              21804],
#             dtype='int64', length=965),
#  'Casa de Condomínio': Int64Index([    5,     6,    12,    16,    42,    58,   166,   168,   183,
#                207,
#              ...
#              21709, 21711, 21719, 21752, 21763, 21764, 21782, 21791, 21801,
#              21820],
#             dtype='int64', length=996),
#  'Casa de Vila': Int64Index([   81,   212,   220,   303,   332,   697,   822,   844,   918,
#               1012,
#              ...
# ...

# %%
Q1 = grupo_tipo.quantile(.25) #calcula o primeiro quartil
Q3 = grupo_tipo.quantile(.75) #calcula o terceiro quartil
IIQ = Q3 - Q1 #calcula o intervalo entre quartis
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
Q1
# Out:
# Tipo
# Apartamento           1700.0
# Casa                  1100.0
# Casa de Condomínio    4000.0
# Casa de Vila           750.0
# Quitinete              900.0
# Name: Valor, dtype: float64

# %%
Q3
# Out:
# Tipo
# Apartamento            5000.0
# Casa                   9800.0
# Casa de Condomínio    15250.0
# Casa de Vila           1800.0
# Quitinete              1500.0
# Name: Valor, dtype: float64

# %%
IIQ
# Out:
# Tipo
# Apartamento            3300.0
# Casa                   8700.0
# Casa de Condomínio    11250.0
# Casa de Vila           1050.0
# Quitinete               600.0
# Name: Valor, dtype: float64

# %%
limite_inferior
# Out:
# Tipo
# Apartamento           -3250.0
# Casa                 -11950.0
# Casa de Condomínio   -12875.0
# Casa de Vila           -825.0
# Quitinete                 0.0
# Name: Valor, dtype: float64

# %%
limite_superior
# Out:
# Tipo
# Apartamento            9950.0
# Casa                  22850.0
# Casa de Condomínio    32125.0
# Casa de Vila           3375.0
# Quitinete              2400.0
# Name: Valor, dtype: float64

# %%
limite_superior['Apartamento']
# Out:
# 9950.0

# %%
dados_new = pd.DataFrame()
for tipo in grupo_tipo.groups.keys(): #seleciona as chaves do dicionário
  eh_tipo = dados['Tipo'] == tipo
  eh_dentro_limite = (dados['Valor'] >= limite_inferior[tipo]) & (dados['Valor'] <= limite_superior[tipo])
  selecao = eh_tipo & eh_dentro_limite
  dados_selecao = dados[selecao]
  dados_new = pd.concat([dados_new, dados_selecao])

# %%
dados_new.boxplot(['Valor'], by = ['Tipo'])

# %%
dados_new.to_csv("aluguel_residencial_sem_outliers.csv", sep = ';', index = False)
